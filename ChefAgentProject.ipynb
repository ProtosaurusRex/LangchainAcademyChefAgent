# %%
from dotenv import load_dotenv

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("Recommend a recipe for dinner tonight.")

response

# %%
system_prompt = """

You are a personal chef and nutritionist.
Using the image and tools provided, recommend recipes and provide nutritional information for the recipes you recommend.

Name: The Name of the dish.
Serving Size: The mass of one serving in grams.
Calories: The number of calories in one serving.
Protein: The amount of protein in one serving in grams.
Carbohydrates: The amount of carbohydrates in one serving in grams.
Fat: The amount of fat in one serving in grams.
Ingredients: A list of the ingredients needed to make the dish.
Instructions: A list of the steps needed to make the dish.

"""

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

question = HumanMessage(content="Reccomend a recipie with chicken that takes less than 20 minutes to prepare")

chef_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

# %%
response = chef_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
chef_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    tools=[web_search]
) 

response = chef_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'afb1d4c647f9a46b2be754087a4849bc.png', 'type': 'image/png', 'size': 2146630, 'content': <memory at 0x000001C52AA2DC00>, 'last_modified': datetime.datetime(2026, 2, 19, 10, 48, 54, 846000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Recommend a recipe based on the ingredients in this image."},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = chef_agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a tasty, colorful recipe using the ingredients I see in your fridge.
#
# Name: Rainbow Veggie Egg Scramble with Fresh Herb Finish
#
# Serving Size: 360 g
#
# Calories: 390 kcal per serving
# Protein: 22 g
# Carbohydrates: 12 g
# Fat: 24 g
#
# Ingredients:
# - 3 large eggs
# - 1 small red bell pepper, diced
# - 1 small yellow bell pepper, diced
# - 1 cup chopped kale (or spinach)
# - 6–8 cherry tomatoes, halved
# - 1 tablespoon olive oil
# - Salt and black pepper to taste
# - Juice of 1/2 lemon (or to taste)
# - 1 tablespoon chopped fresh parsley (optional)
# - Optional side: citrus fruits (orange segments or apple slices) for a fresh finish
#
# Instructions:
# 1) Prep vegetables: Dice the bell peppers, roughly chop the kale, and halve the cherry tomatoes.
# 2) Sauté veggies: Heat olive oil in a nonstick skillet over medium heat. Add peppers and kale; cook 3–4 minutes until they begin to soften.
# 3) Scramble eggs: In a bowl, whisk eggs with a pinch of salt and pepper. Pour into the pan with veggies. Gently stir to form soft curds, cooking until just set. Add the cherry tomatoes in the last minute to warm through.
# 4) Finish: Remove from heat. Drizzle with lemon juice and sprinkle with fresh parsley.
# 5) Serve: Plate the scramble and, if you like, add a small side of citrus fruits for a refreshing balance.
#
# Nutrition notes:
# - The olive oil adds healthy fats and flavor; you can reduce to 1 teaspoon for a lighter version.
# - To lower calories and fat, swap 1 of the whole eggs for 2 extra whites (e.g., 2 whole eggs + 2 whites).
# - This dish uses a mix of colorful veggies to provide fiber, vitamins A/C, and minerals with a protein boost from the eggs.
#
# If you want, I can tailor this to specific macros or swap in any other ingredients you have on hand (e.g., onions, zucchini, or mushrooms).
